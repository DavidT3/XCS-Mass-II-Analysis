# %% [markdown]
# # New SDSSRM-XCS Relations: $M_{\rm{tot}}$-$L_{\rm{X}}$

# %% [markdown]
# This section of the project fits scaling relations to the measurements of properties made in the first paper of this series [(Turner et al. 2024)](https://ui.adsabs.harvard.edu/abs/2025MNRAS.tmp...10T/abstract). Masses are from the 'hydrostatic equilibrium' method, fully explained in the initial paper.
#
# Here we focus on scaling relations between the total mass of galaxy clusters and groups ($M_{\rm{tot}}$, or $M^{\rm{tot}}_{\Delta}$ within an overdensity radius $R_{\Delta}$) and the cluster/group X-ray luminosity ($L_{\rm{X}}$, or $L^{0.5-2.0}_{\rm{X},\Delta}$ within $R_{\Delta}$ and 0.5-2.0 keV energy bounds). If present in a property name, 'ce' means 'core-excised', normally 0.15$R_{500}$. When we refer to the bolometric (with shorthand 'bol') we are talking about the entire energy range of the telescope.
#
# Relation fits are performed using the XGA interface to the R scaling-relation fitting package LIRA, see the paper for full details.

# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import numpy as np
from astropy.units import Quantity
from astropy.cosmology import LambdaCDM

# This adds the directory above to the path, allowing me to import the common functions that I've written in
#  common.py - this just saves me repeating boring code and makes sure its all consistent
import sys
sys.path.insert(0, '..')
from common import xcs_cosmo, lx_norm, m_norm

import xga
from xga.relations.fit import scaling_relation_lira

# %% [markdown]
# ## Normalisation values

# %% [markdown]
# These are used when fitting the scaling relations to normalise the data, and are kept the same throughout this entire project:

# %%
lx_norm
# Out:
# <Quantity 1.e+44 erg / s>

# %%
m_norm
# Out:
# <Quantity 1.e+14 solMass>

# %% [markdown]
# ## Cosmological model

# %% [markdown]
# We use the same cosmology as was utilised in the initial paper of this series:

# %%
xcs_cosmo
# Out:
# LambdaCDM(name=None, H0=<Quantity 70. km / (Mpc s)>, Om0=0.3, Ode0=0.7, Tcmb0=<Quantity 0. K>, Neff=3.04, m_nu=None, Ob0=None)

# %% [markdown]
# ## Loading data files

# %% [markdown]
# Important considerations for this dataset:
# * The X-ray cluster sample was originally assembled and analysed by [Giles et al. (2022)](https://ui.adsabs.harvard.edu/abs/2022MNRAS.516.3878G/abstract) - when we say 'SDSSRM-XCS' we are specifically referring to the volume limited ($0.1<z<0.35$) sample with fractional temperature errors of less than 25% - contains 150 clusters.
# * SDSSRM-XCS is ultimately an *optically selected* sample however, as the original X-ray work (see above) found X-ray counterparts to clusters selected from the redMaPPer catalog of galaxy clusters produced from SDSS photometry [(Rykoff et al. 2014)](http://adsabs.harvard.edu/abs/2014ApJ...785..104R).
# * These galaxy clusters were then further analysed in the first paper of this series [(Turner et al. 2024)](https://ui.adsabs.harvard.edu/abs/2025MNRAS.tmp...10T/abstract), measuring radial profiles of density and temperature that were used to calculate hydrostatic and gas masses.

# %% [markdown]
# ### SDSSRM-XCS base sample

# %%
sdssxcs_base = pd.read_csv("../../sample_files/SDSSRM-XCS_base_sample.csv")
sdssxcs_base.head(6)
# Out:
#            name  MEM_MATCH_ID  xapa_ra  xapa_dec       z      r500   r500-  \
# 0   SDSSXCS-124           124  0.80058  -6.09182  0.2475  1181.028  21.202
# 1  SDSSXCS-2789          2789  0.95554   2.06802  0.1053  1007.861  17.194
# 2   SDSSXCS-290           290  2.72264  29.16102  0.3485   913.052  30.879
# 3  SDSSXCS-1018          1018  4.40633  -0.87619  0.2144   902.259  22.445
# 4   SDSSXCS-134           134  4.90839   3.60982  0.2773  1123.321  19.219
# 5   SDSSXCS-119           119  8.46470  -7.86290  0.3042   944.275  46.422
#
#     r500+  richness  richness_err                   XCS_NAME
# 0  23.203   109.550         4.490  XMMXCS J000312.1-060530.5
# 1  17.202    38.904         2.830  XMMXCS J000349.3+020404.8
# 2  31.210   105.096         5.994  XMMXCS J001053.4+290939.6
# 3  23.366    56.997         3.219  XMMXCS J001737.5-005234.2
# 4  19.226   108.604         4.792  XMMXCS J001938.0+033635.3
# 5  46.747   128.192         5.697  XMMXCS J003351.5-075146.4

# %% [markdown]
# Calculating E(z) values for these clusters:

# %%
sdssxcs_base['E'] = xcs_cosmo.efunc(sdssxcs_base['z'].values)

# %% [markdown]
# ### SDSSRM-XCS $T_{\rm{X}}$ and $L_{\rm{X}}$

# %%
sdssxcs_txlx = pd.read_csv("../../sample_files/paper_one_results/sdssrm-xcs_txlx_v1.0.0.csv")
sdssxcs_txlx.head(6)
# Out:
#            name   Tx_500   Tx_500-   Tx_500+      Lx52_500     Lx52_500-  \
# 0   SDSSXCS-124  6.92000  0.116389  0.111642  5.310408e+44  2.494586e+42
# 1  SDSSXCS-2789  4.54033  0.073600  0.074023  1.029575e+44  5.149604e+41
# 2   SDSSXCS-290  5.31681  0.297854  0.336308  2.856695e+44  5.917234e+42
# 3  SDSSXCS-1018  3.90154  0.143544  0.151498  8.044819e+43  1.441322e+42
# 4   SDSSXCS-134  6.72622  0.116523  0.116565  4.811899e+44  2.458557e+42
# 5   SDSSXCS-119  4.93456  0.400268  0.456173  2.049789e+44  5.182032e+42
#
#       Lx52_500+     Lxbol_500    Lxbol_500-    Lxbol_500+  Tx_2500  Tx_2500-  \
# 0  3.193270e+42  2.039754e+45  2.082091e+43  1.712354e+43  7.08946  0.097823
# 1  6.858712e+41  3.213527e+44  3.914562e+42  3.124017e+42  4.44237  0.057404
# 2  7.322989e+42  9.632533e+44  4.005991e+43  3.207763e+43  5.41431  0.259989
# 3  9.241468e+41  2.335851e+44  6.385493e+42  4.924304e+42  4.09555  0.108381
# ...

# %% [markdown]
# ### SDSSRM-XCS masses

# %%
sdssxcs_mass = pd.read_csv("../../sample_files/paper_one_results/sdssrm-xcs_mass_v1.0.0.csv")
sdssxcs_mass.head(6)
# Out:
#            name    Mhy500   Mhy500-   Mhy500+     Mg500    Mg500-    Mg500+  \
# 0   SDSSXCS-124  7.634491  1.286289  1.029318  0.869914  0.002841  0.005951
# 1  SDSSXCS-2789  7.820374  1.259755  1.447212  0.218603  0.002491  0.002496
# 2   SDSSXCS-290  2.961604  0.369827  0.382523  0.427969  0.002132  0.002098
# 3  SDSSXCS-1018  5.067958  1.015270  0.969362  0.210208  0.001929  0.001917
# 4   SDSSXCS-134  6.802619  0.782566  0.772819  0.767290  0.002149  0.002170
# 5   SDSSXCS-119       NaN       NaN       NaN       NaN       NaN       NaN
#
#     Mhy2500  Mhy2500-  Mhy2500+    Mg2500   Mg2500-   Mg2500+  Mhy500_wraderr  \
# 0  2.621329  0.112240  0.137975  0.321744  0.000722  0.000734        7.635562
# 1  1.602926  0.101929  0.109311  0.097414  0.000324  0.000329        7.823912
# 2  1.467429  0.175603  0.290465  0.134154  0.000759  0.000773        2.959792
# 3  1.128892  0.103503  0.149913  0.084371  0.000350  0.000359        5.072697
# ...

# %% [markdown]
# ### Combining tables

# %%
sdssxcs_samp = pd.merge(sdssxcs_base, sdssxcs_txlx, left_on='name', right_on='name', how='outer')
sdssxcs_samp = pd.merge(sdssxcs_samp, sdssxcs_mass, left_on='name', right_on='name', how='outer')

# %%
sdssxcs_samp.columns
# Out:
# Index(['name', 'MEM_MATCH_ID', 'xapa_ra', 'xapa_dec', 'z', 'r500', 'r500-',
#        'r500+', 'richness', 'richness_err', 'XCS_NAME', 'E', 'Tx_500',
#        'Tx_500-', 'Tx_500+', 'Lx52_500', 'Lx52_500-', 'Lx52_500+', 'Lxbol_500',
#        'Lxbol_500-', 'Lxbol_500+', 'Tx_2500', 'Tx_2500-', 'Tx_2500+',
#        'Lx52_2500', 'Lx52_2500-', 'Lx52_2500+', 'Lxbol_2500', 'Lxbol_2500-',
#        'Lxbol_2500+', 'Tx_500ce', 'Tx_500ce-', 'Tx_500ce+', 'Lx52_500ce',
#        'Lx52_500ce-', 'Lx52_500ce+', 'Lxbol_500ce', 'Lxbol_500ce-',
#        'Lxbol_500ce+', 'Mhy500', 'Mhy500-', 'Mhy500+', 'Mg500', 'Mg500-',
#        'Mg500+', 'Mhy2500', 'Mhy2500-', 'Mhy2500+', 'Mg2500', 'Mg2500-',
#        'Mg2500+', 'Mhy500_wraderr', 'Mhy500_wraderr-', 'Mhy500_wraderr+',
#        'Mg500_wraderr', 'Mg500_wraderr-', 'Mg500_wraderr+', 'Mhy2500_wraderr',
#        'Mhy2500_wraderr-', 'Mhy2500_wraderr+', 'Mg2500_wraderr',
#        'Mg2500_wraderr-', 'Mg2500_wraderr+'],
#       dtype='object')

# %%
# sdssxcs_samp = sdssxcs_samp[~sdssxcs_samp['name'].isin(['SDSSXCS-22', 'SDSSXCS-1131'])]

# %% [markdown]
# ## Fitting scaling relations

# %% [markdown]
# ### $M^{\rm{tot}}_{500}$-$L^{0.5-2.0}_{\rm{X,500}}$

# %%
# Setting up property variables in astropy quantity objects
mtot500 = Quantity(sdssxcs_samp[['Mhy500_wraderr', 'Mhy500_wraderr-', 'Mhy500_wraderr+']].values*1e+14, 'Msun')\
    *(sdssxcs_samp['E'].values[..., None]**2)
lx500_52 = Quantity(sdssxcs_samp[['Lx52_500', 'Lx52_500-','Lx52_500+']].values, 'erg/s')

mtot500_lx52_500 = scaling_relation_lira(mtot500[:, 0], mtot500[:, 1:], lx500_52[:, 0], lx500_52[:, 1:], m_norm, lx_norm, 
                                         y_name=r"$E(z)^{2}M^{\rm{tot}}_{500}$", x_name=r"$L^{0.5-2.0}_{\rm{X,500}}$", 
                                         dim_hubb_ind=2, point_names=sdssxcs_samp['name'].values)
mtot500_lx52_500.model_colour = 'darkorange'
mtot500_lx52_500.author = 'Turner et al.'
mtot500_lx52_500.year = 2025
mtot500_lx52_500.name = r'Turner et al. $E(z)^{2}M^{\rm{tot}}_{500}$-$L^{0.5-2.0}_{\rm{X,500}}$'
mtot500_lx52_500.save("../../outputs/scaling_relations/sdssrm-xcs_new/mtot-lx/turner2025_mtot500_lx52_500.xgarel")
# Out:
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/relations/fit.py:414: UserWarning: 46 sources have NaN values or negative uncertainties and have been excluded
#   third_dim_info = _fit_initialise(y_values, y_errs, x_values, x_errs, y_norm, x_norm, True, point_names,
# R[write to console]: module mix loaded
#   |**************************************************| 100%
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/relations/fit.py:450: UserWarning: 46 sources have NaN values or negative uncertainties and have been excluded
#   throw_away, sec_throw_away = _fit_initialise(y_values, y_errs, x_values, x_errs, y_norm, x_norm)

# %%
print("Slope of {v:.3f} ± {e:.3f}\n".format(v=mtot500_lx52_500.pars[0][0], e=mtot500_lx52_500.pars[0][1]))
print("Normalisation of {v:.3f} ± {e:.3f}\n".format(v=mtot500_lx52_500.pars[1][0], e=mtot500_lx52_500.pars[1][1]))
print("Scatter of {v:.3f} ± {e:.3f}".format(v=mtot500_lx52_500.scatter_par[0], e=mtot500_lx52_500.scatter_par[1]))
# Out:
# Slope of 0.409 ± 0.044
#
# Normalisation of 4.398 ± 0.250
#
# Scatter of 0.216 ± 0.018

# %%
mtot500_lx52_500.view(figsize=(7.3, 7), y_lims=Quantity([1e+13, 4e+15], 'Msun'), 
                      save_path="../../outputs/figures/scaling_relations/sdssrm-xcs_new/mtot-lx/turner2025_mtot500_lx52_500.pdf")

# %% [markdown]
# ### $M^{\rm{tot}}_{500}$-$L^{0.5-2.0}_{\rm{X,500ce}}$

# %%
# Setting up property variables in astropy quantity objects
mtot500 = Quantity(sdssxcs_samp[['Mhy500_wraderr', 'Mhy500_wraderr-', 'Mhy500_wraderr+']].values*1e+14, 'Msun')\
    *(sdssxcs_samp['E'].values[..., None]**2)
lx500ce_52 = Quantity(sdssxcs_samp[['Lx52_500ce', 'Lx52_500ce-','Lx52_500ce+']].values, 'erg/s')

mtot500_lx52_500ce = scaling_relation_lira(mtot500[:, 0], mtot500[:, 1:], lx500ce_52[:, 0], lx500ce_52[:, 1:], m_norm, lx_norm, 
                                           y_name=r"$E(z)^{2}M^{\rm{tot}}_{500}$", x_name=r"$L^{0.5-2.0}_{\rm{X,500ce}}$", 
                                           dim_hubb_ind=2, point_names=sdssxcs_samp['name'].values)
mtot500_lx52_500ce.model_colour = 'rosybrown'
mtot500_lx52_500ce.author = 'Turner et al.'
mtot500_lx52_500ce.year = 2025
mtot500_lx52_500ce.name = r'Turner et al. $E(z)^{2}M^{\rm{tot}}_{500}$-$L^{0.5-2.0}_{\rm{X,500ce}}$'
mtot500_lx52_500ce.save("../../outputs/scaling_relations/sdssrm-xcs_new/mtot-lx/turner2025_mtot500_lx52_500ce.xgarel")
# Out:
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/relations/fit.py:414: UserWarning: 46 sources have NaN values or negative uncertainties and have been excluded
#   third_dim_info = _fit_initialise(y_values, y_errs, x_values, x_errs, y_norm, x_norm, True, point_names,
#   |**************************************************| 100%
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/relations/fit.py:450: UserWarning: 46 sources have NaN values or negative uncertainties and have been excluded
#   throw_away, sec_throw_away = _fit_initialise(y_values, y_errs, x_values, x_errs, y_norm, x_norm)

# %%
print("Slope of {v:.3f} ± {e:.3f}\n".format(v=mtot500_lx52_500ce.pars[0][0], e=mtot500_lx52_500ce.pars[0][1]))
print("Normalisation of {v:.3f} ± {e:.3f}\n".format(v=mtot500_lx52_500ce.pars[1][0], e=mtot500_lx52_500ce.pars[1][1]))
print("Scatter of {v:.3f} ± {e:.3f}".format(v=mtot500_lx52_500ce.scatter_par[0], e=mtot500_lx52_500ce.scatter_par[1]))
# Out:
# Slope of 0.465 ± 0.046
#
# Normalisation of 5.074 ± 0.258
#
# Scatter of 0.204 ± 0.017

# %%
mtot500_lx52_500ce.view(figsize=(7.3, 7), y_lims=Quantity([1e+13, 4e+15], 'Msun'), 
                        save_path="../../outputs/figures/scaling_relations/sdssrm-xcs_new/mtot-lx/turner2025_mtot500_lx52_500ce.pdf")

# %% [markdown]
# ### $M^{\rm{tot}}_{500}$-$L^{\rm{bol}}_{\rm{X,500}}$

# %%
# Setting up property variables in astropy quantity objects
mtot500 = Quantity(sdssxcs_samp[['Mhy500_wraderr', 'Mhy500_wraderr-', 'Mhy500_wraderr+']].values*1e+14, 'Msun')\
    *(sdssxcs_samp['E'].values[..., None]**2)
lx500_bol = Quantity(sdssxcs_samp[['Lxbol_500', 'Lxbol_500-','Lxbol_500+']].values, 'erg/s')

mtot500_lxbol_500 = scaling_relation_lira(mtot500[:, 0], mtot500[:, 1:], lx500_bol[:, 0], lx500_bol[:, 1:], m_norm, lx_norm, 
                                          y_name=r"$E(z)^{2}M^{\rm{tot}}_{500}$", x_name=r"$L^{\rm{bol}}_{\rm{X,500}}$", 
                                          dim_hubb_ind=2, point_names=sdssxcs_samp['name'].values)
mtot500_lxbol_500.model_colour = 'darkgreen'
mtot500_lxbol_500.author = 'Turner et al.'
mtot500_lxbol_500.year = 2025
mtot500_lxbol_500.name = r'Turner et al. $E(z)^{2}M^{\rm{tot}}_{500}$-$L^{\rm{bol}}_{\rm{X,500}}$'
mtot500_lxbol_500.save("../../outputs/scaling_relations/sdssrm-xcs_new/mtot-lx/turner2025_mtot500_lxbol_500.xgarel")
# Out:
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/relations/fit.py:414: UserWarning: 46 sources have NaN values or negative uncertainties and have been excluded
#   third_dim_info = _fit_initialise(y_values, y_errs, x_values, x_errs, y_norm, x_norm, True, point_names,
#   |**************************************************| 100%
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/relations/fit.py:450: UserWarning: 46 sources have NaN values or negative uncertainties and have been excluded
#   throw_away, sec_throw_away = _fit_initialise(y_values, y_errs, x_values, x_errs, y_norm, x_norm)

# %%
print("Slope of {v:.3f} ± {e:.3f}\n".format(v=mtot500_lxbol_500.pars[0][0], e=mtot500_lxbol_500.pars[0][1]))
print("Normalisation of {v:.3f} ± {e:.3f}\n".format(v=mtot500_lxbol_500.pars[1][0], e=mtot500_lxbol_500.pars[1][1]))
print("Scatter of {v:.3f} ± {e:.3f}".format(v=mtot500_lxbol_500.scatter_par[0], e=mtot500_lxbol_500.scatter_par[1]))
# Out:
# Slope of 0.375 ± 0.037
#
# Normalisation of 2.898 ± 0.230
#
# Scatter of 0.205 ± 0.017

# %%
mtot500_lxbol_500.view(figsize=(7.3, 7), y_lims=Quantity([1e+13, 4e+15], 'Msun'), 
                       save_path="../../outputs/figures/scaling_relations/sdssrm-xcs_new/mtot-lx/turner2025_mtot500_lxbol_500.pdf")

# %% [markdown]
# ### $M^{\rm{tot}}_{500}$-$L^{\rm{bol}}_{\rm{X,500ce}}$

# %%
# Setting up property variables in astropy quantity objects
mtot500 = Quantity(sdssxcs_samp[['Mhy500_wraderr', 'Mhy500_wraderr-', 'Mhy500_wraderr+']].values*1e+14, 'Msun')\
    *(sdssxcs_samp['E'].values[..., None]**2)
lx500ce_bol = Quantity(sdssxcs_samp[['Lxbol_500ce', 'Lxbol_500ce-','Lxbol_500ce+']].values, 'erg/s')

mtot500_lxbol_500ce = scaling_relation_lira(mtot500[:, 0], mtot500[:, 1:], lx500ce_bol[:, 0], lx500ce_bol[:, 1:], m_norm, lx_norm, 
                                          y_name=r"$E(z)^{2}M^{\rm{tot}}_{500}$", x_name=r"$L^{\rm{bol}}_{\rm{X,500ce}}$", 
                                          dim_hubb_ind=2, point_names=sdssxcs_samp['name'].values)
mtot500_lxbol_500ce.model_colour = 'lightseagreen'
mtot500_lxbol_500ce.author = 'Turner et al.'
mtot500_lxbol_500ce.year = 2025
mtot500_lxbol_500ce.name = r'Turner et al. $E(z)^{2}M^{\rm{tot}}_{500}$-$L^{\rm{bol}}_{\rm{X,500ce}}$'
mtot500_lxbol_500ce.save("../../outputs/scaling_relations/sdssrm-xcs_new/mtot-lx/turner2025_mtot500_lxbol_500ce.xgarel")
# Out:
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/relations/fit.py:414: UserWarning: 46 sources have NaN values or negative uncertainties and have been excluded
#   third_dim_info = _fit_initialise(y_values, y_errs, x_values, x_errs, y_norm, x_norm, True, point_names,
#   |**************************************************| 100%
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/relations/fit.py:450: UserWarning: 46 sources have NaN values or negative uncertainties and have been excluded
#   throw_away, sec_throw_away = _fit_initialise(y_values, y_errs, x_values, x_errs, y_norm, x_norm)

# %%
print("Slope of {v:.3f} ± {e:.3f}\n".format(v=mtot500_lxbol_500ce.pars[0][0], e=mtot500_lxbol_500ce.pars[0][1]))
print("Normalisation of {v:.3f} ± {e:.3f}\n".format(v=mtot500_lxbol_500ce.pars[1][0], e=mtot500_lxbol_500ce.pars[1][1]))
print("Scatter of {v:.3f} ± {e:.3f}".format(v=mtot500_lxbol_500ce.scatter_par[0], e=mtot500_lxbol_500ce.scatter_par[1]))
# Out:
# Slope of 0.416 ± 0.038
#
# Normalisation of 3.146 ± 0.216
#
# Scatter of 0.195 ± 0.016

# %%
mtot500_lxbol_500ce.view(figsize=(7.3, 7), y_lims=Quantity([1e+13, 4e+15], 'Msun'), 
                         save_path="../../outputs/figures/scaling_relations/sdssrm-xcs_new/mtot-lx/turner2025_mtot500_lxbol_500ce.pdf")

# %% [markdown]
# ### $M^{\rm{tot}}_{2500}$-$L^{0.5-2.0}_{\rm{X,2500}}$

# %%
# Setting up property variables in astropy quantity objects
mtot2500 = Quantity(sdssxcs_samp[['Mhy2500_wraderr', 'Mhy2500_wraderr-', 'Mhy2500_wraderr+']].values*1e+14, 'Msun')\
    *(sdssxcs_samp['E'].values[..., None]**2)
lx2500_52 = Quantity(sdssxcs_samp[['Lx52_2500', 'Lx52_2500-','Lx52_2500+']].values, 'erg/s')

mtot2500_lx52_2500 = scaling_relation_lira(mtot2500[:, 0], mtot2500[:, 1:], lx2500_52[:, 0], lx2500_52[:, 1:], m_norm, lx_norm, 
                                           y_name=r"$E(z)^{2}M^{\rm{tot}}_{2500}$", x_name=r"$L^{0.5-2.0}_{\rm{X,2500}}$", 
                                           dim_hubb_ind=2, point_names=sdssxcs_samp['name'].values)
mtot2500_lx52_2500.model_colour = 'orchid'
mtot2500_lx52_2500.author = 'Turner et al.'
mtot2500_lx52_2500.year = 2025
mtot2500_lx52_2500.name = r'Turner et al. $E(z)^{2}M^{\rm{tot}}_{2500}$-$L^{0.5-2.0}_{\rm{X,2500}}$'
mtot2500_lx52_2500.save("../../outputs/scaling_relations/sdssrm-xcs_new/mtot-lx/turner2025_mtot2500_lx52_2500.xgarel")
# Out:
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/relations/fit.py:414: UserWarning: 59 sources have NaN values or negative uncertainties and have been excluded
#   third_dim_info = _fit_initialise(y_values, y_errs, x_values, x_errs, y_norm, x_norm, True, point_names,
#   |**************************************************| 100%
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/relations/fit.py:450: UserWarning: 59 sources have NaN values or negative uncertainties and have been excluded
#   throw_away, sec_throw_away = _fit_initialise(y_values, y_errs, x_values, x_errs, y_norm, x_norm)

# %%
print("Slope of {v:.3f} ± {e:.3f}\n".format(v=mtot2500_lx52_2500.pars[0][0], e=mtot2500_lx52_2500.pars[0][1]))
print("Normalisation of {v:.3f} ± {e:.3f}\n".format(v=mtot2500_lx52_2500.pars[1][0], e=mtot2500_lx52_2500.pars[1][1]))
print("Scatter of {v:.3f} ± {e:.3f}".format(v=mtot2500_lx52_2500.scatter_par[0], e=mtot2500_lx52_2500.scatter_par[1]))
# Out:
# Slope of 0.414 ± 0.035
#
# Normalisation of 1.778 ± 0.077
#
# Scatter of 0.166 ± 0.014

# %%
mtot2500_lx52_2500.view(figsize=(7.3, 7), y_lims=Quantity([1e+13, 9e+14], 'Msun'), 
                         save_path="../../outputs/figures/scaling_relations/sdssrm-xcs_new/mtot-lx/turner2025_mtot2500_lx52_2500.pdf")

# %% [markdown]
# ### $M^{\rm{tot}}_{2500}$-$L^{\rm{bol}}_{\rm{X,2500}}$

# %%
# Setting up property variables in astropy quantity objects
mtot2500 = Quantity(sdssxcs_samp[['Mhy2500_wraderr', 'Mhy2500_wraderr-', 'Mhy2500_wraderr+']].values*1e+14, 'Msun')\
    *(sdssxcs_samp['E'].values[..., None]**2)
lx2500_bol = Quantity(sdssxcs_samp[['Lxbol_2500', 'Lxbol_2500-','Lxbol_2500+']].values, 'erg/s')

mtot2500_lxbol_2500 = scaling_relation_lira(mtot2500[:, 0], mtot2500[:, 1:], lx2500_bol[:, 0], lx2500_bol[:, 1:], m_norm, lx_norm, 
                                            y_name=r"$E(z)^{2}M^{\rm{tot}}_{2500}$", x_name=r"$L^{\rm{bol}}_{\rm{X,2500}}$", 
                                            dim_hubb_ind=2, point_names=sdssxcs_samp['name'].values)
mtot2500_lxbol_2500.model_colour = 'thistle'
mtot2500_lxbol_2500.author = 'Turner et al.'
mtot2500_lxbol_2500.year = 2025
mtot2500_lxbol_2500.name = r'Turner et al. $E(z)^{2}M^{\rm{tot}}_{2500}$-$L^{\rm{bol}}_{\rm{X,2500}}$'
mtot2500_lxbol_2500.save("../../outputs/scaling_relations/sdssrm-xcs_new/mtot-lx/turner2025_mtot2500_lxbol_2500.xgarel")
# Out:
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/relations/fit.py:414: UserWarning: 59 sources have NaN values or negative uncertainties and have been excluded
#   third_dim_info = _fit_initialise(y_values, y_errs, x_values, x_errs, y_norm, x_norm, True, point_names,
#   |**************************************************| 100%
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/relations/fit.py:450: UserWarning: 59 sources have NaN values or negative uncertainties and have been excluded
#   throw_away, sec_throw_away = _fit_initialise(y_values, y_errs, x_values, x_errs, y_norm, x_norm)

# %%
print("Slope of {v:.3f} ± {e:.3f}\n".format(v=mtot2500_lxbol_2500.pars[0][0], e=mtot2500_lxbol_2500.pars[0][1]))
print("Normalisation of {v:.3f} ± {e:.3f}\n".format(v=mtot2500_lxbol_2500.pars[1][0], e=mtot2500_lxbol_2500.pars[1][1]))
print("Scatter of {v:.3f} ± {e:.3f}".format(v=mtot2500_lxbol_2500.scatter_par[0], e=mtot2500_lxbol_2500.scatter_par[1]))
# Out:
# Slope of 0.381 ± 0.029
#
# Normalisation of 1.145 ± 0.061
#
# Scatter of 0.152 ± 0.013

# %%
mtot2500_lxbol_2500.view(figsize=(7.3, 7), y_lims=Quantity([1e+13, 9e+14], 'Msun'), 
                         save_path="../../outputs/figures/scaling_relations/sdssrm-xcs_new/mtot-lx/turner2025_mtot2500_lxbol_2500.pdf")

# %% [markdown]
# ### Combined contours

# %%
comb_rel = (mtot500_lx52_500 + mtot500_lx52_500ce + mtot500_lxbol_500 + mtot500_lxbol_500ce + 
            mtot2500_lx52_2500 + mtot2500_lxbol_2500)
comb_rel.view_corner(save_path="../../outputs/figures/scaling_relations/sdssrm-xcs_new/mtot-lx/turner2025_mtot_lx_contours.pdf")
# Out:
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/products/relation.py:1243: UserWarning: Not all of these ScalingRelations have the same x-axis names.
#   warn('Not all of these ScalingRelations have the same x-axis names.')
# /Users/dt237/software/anaconda3/envs/xga_env/lib/python3.12/site-packages/xga/products/relation.py:1250: UserWarning: Not all of these ScalingRelations have the same y-axis names.
#   warn('Not all of these ScalingRelations have the same y-axis names.')
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
# Removed no burn in
