# %% [markdown]
# # Explore SDSSRM-XCS Scatter: $M_{\rm{tot}}$-$M_{\rm{gas}}$ mass dependent scatter

# %% [markdown]
# This section of the project explores potential reasons and diagnostics of galaxy cluster/group scaling relation scatter using the new SDSSRM-XCS relations constructed in this work from the properties measured in the first paper of this series [(Turner et al. 2024)](https://ui.adsabs.harvard.edu/abs/2025MNRAS.tmp...10T/abstract).
#
# Here we perform a very simple investigation of an apparent dividing line in $M_{\rm{gas}}$ evident in the $M^{\rm{tot}}_{2500}$-$M^{\rm{gas}}_{2500}$ relation, between higher mass clusters whose $M_{\rm{tot}}$ and $M_{\rm{gas}}$ appear tightly correlated, and those that do not. We split the dataset into two samples (above and below $M^{\rm{gas}}_{2500}=2\times10^{13}\:M_{\rm{\odot}}$), and fit two separate relations - the measured scatter of each allows us to quantify the difference above and below the $M^{\rm{gas}}_{2500}$ line.
#
# We also perform a similar investigation on the $R_{500}$ variant of this relation - though we do not see as obvious of a scatter dividing line between low and high gas mass systems. Splitting the clusters into two samples and fitting scaling relations will provide a more concrete answer than visual assessment.
#
# Scaling relation fits were performed using the XGA interface to the R scaling-relation fitting package LIRA, see the paper for full details.

# %% [markdown]
# ## Main takeaways

# %% [markdown]
# In summary:
#
# * We split SDSSRM-XCS galaxy clusters with $M^{\rm{tot}}_{2500}$ and $M^{\rm{gas}}_{2500}$ measurements into two samples - above and below $M^{\rm{gas}}_{2500}=2\times10^{13}\:M_{\rm{\odot}}$. $M^{\rm{tot}}_{2500}$-$M^{\rm{gas}}_{2500}$ scaling relations are fit to both sub-samples in order to assess any difference in scatter.
# * There is a very significant difference in the measured scatter between the two sub-samples; the scatter of clusters $M^{\rm{gas}}_{2500}<2\times10^{13}\:M_{\rm{\odot}}$ is $\mathbf{{\sim}2.4\times}$ larger than that measured for $M^{\rm{gas}}_{2500}\ge2\times10^{13}\:M_{\rm{\odot}}$.
# * The same process is applied to the $M^{\rm{tot}}_{500}$-$M^{\rm{gas}}_{500}$ relation, in an attempt to determine if there is a difference in scatter with gas mass to be found there - _during initial inspection, we did not observe the same sort of clear divide we saw in the $M_{2500}$ relation_, but we wish to test that in a more quantified manner.
# * Splitting the sample on $M^{\rm{gas}}_{500}=6\times10^{13}\:M_{\rm{\odot}}$ and fitting the sub-samples, we do find that the lower gas-mass clusters have a significantly higher ($\mathbf{{\sim}1.9\times}$) scatter than the higher gas-mass systems.

# %% [markdown]
# ## Import Statements

# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
import numpy as np
from astropy.units import Quantity
from astropy.cosmology import LambdaCDM
import pickle
import matplotlib
from matplotlib import pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from tqdm import tqdm

# This adds the directory above to the path, allowing me to import the common functions that I've written in
#  common.py - this just saves me repeating boring code and makes sure its all consistent
import sys
sys.path.insert(0, '..')
from common import xcs_cosmo, m_norm, mgas_norm

import xga
from xga.relations.fit import scaling_relation_lira

# Setting up this constant that controls the confidence intervals calculated for the scatter change
#  distributions - makes it much easier to change the exact value later if we need too. This is 
#  what is going to be used to define the scatter-dominating clusters.
CONF_PERC = 90

# %% [markdown]
# ## Loading data files and relations

# %% [markdown]
# We load the 'base' SDSSRM-XCS sample file, containing some basic information about galaxy cluster names, positions, and redshifts. We also load the SDSSRM-XCS cluster property results files from the first paper of this series.
#
# The scaling relations which we are performing our bootstrapping scatter assessment on are also loaded in here.

# %% [markdown]
# ### SDSSRM-XCS base sample

# %%
sdssxcs_base = pd.read_csv("../../sample_files/SDSSRM-XCS_base_sample.csv")
sdssxcs_base.head(6)
# Out:
#            name  MEM_MATCH_ID  xapa_ra  xapa_dec     rm_ra     rm_dec       z  \
# 0   SDSSXCS-124           124  0.80058  -6.09182  0.798261  -6.091694  0.2475
# 1  SDSSXCS-2789          2789  0.95554   2.06802  0.956981   2.066469  0.1053
# 2   SDSSXCS-290           290  2.72264  29.16102  2.714137  29.161154  0.3485
# 3  SDSSXCS-1018          1018  4.40633  -0.87619  4.406711  -0.878340  0.2144
# 4   SDSSXCS-134           134  4.90839   3.60982  4.911069   3.599257  0.2773
# 5   SDSSXCS-119           119  8.46470  -7.86290  8.471426  -7.869543  0.3042
#
#        r500   r500-   r500+  richness  richness_err  \
# 0  1181.028  21.202  23.203   109.550         4.490
# 1  1007.861  17.194  17.202    38.904         2.830
# 2   913.052  30.879  31.210   105.096         5.994
# 3   902.259  22.445  23.366    56.997         3.219
# 4  1123.321  19.219  19.226   108.604         4.792
# 5   944.275  46.422  46.747   128.192         5.697
#
# ...

# %% [markdown]
# Calculating E(z) values for these clusters:

# %%
sdssxcs_base['E'] = xcs_cosmo.efunc(sdssxcs_base['z'].values)

# %% [markdown]
# ### SDSSRM-XCS $T_{\rm{X}}$ and $L_{\rm{X}}$

# %%
sdssxcs_txlx = pd.read_csv("../../sample_files/paper_one_results/sdssrm-xcs_txlx_v1.0.0.csv")
sdssxcs_txlx.head(6)
# Out:
#            name   Tx_500   Tx_500-   Tx_500+      Lx52_500     Lx52_500-  \
# 0   SDSSXCS-124  6.92000  0.116389  0.111642  5.310408e+44  2.494586e+42
# 1  SDSSXCS-2789  4.54033  0.073600  0.074023  1.029575e+44  5.149604e+41
# 2   SDSSXCS-290  5.31681  0.297854  0.336308  2.856695e+44  5.917234e+42
# 3  SDSSXCS-1018  3.90154  0.143544  0.151498  8.044819e+43  1.441322e+42
# 4   SDSSXCS-134  6.72622  0.116523  0.116565  4.811899e+44  2.458557e+42
# 5   SDSSXCS-119  4.93456  0.400268  0.456173  2.049789e+44  5.182032e+42
#
#       Lx52_500+     Lxbol_500    Lxbol_500-    Lxbol_500+  Tx_2500  Tx_2500-  \
# 0  3.193270e+42  2.039754e+45  2.082091e+43  1.712354e+43  7.08946  0.097823
# 1  6.858712e+41  3.213527e+44  3.914562e+42  3.124017e+42  4.44237  0.057404
# 2  7.322989e+42  9.632533e+44  4.005991e+43  3.207763e+43  5.41431  0.259989
# 3  9.241468e+41  2.335851e+44  6.385493e+42  4.924304e+42  4.09555  0.108381
# ...

# %% [markdown]
# ### SDSSRM-XCS masses

# %%
sdssxcs_mass = pd.read_csv("../../sample_files/paper_one_results/sdssrm-xcs_mass_v1.0.0.csv")
sdssxcs_mass.head(6)
# Out:
#            name    Mhy500   Mhy500-   Mhy500+     Mg500    Mg500-    Mg500+  \
# 0   SDSSXCS-124  7.634491  1.286289  1.029318  0.869914  0.002841  0.005951
# 1  SDSSXCS-2789  7.820374  1.259755  1.447212  0.218603  0.002491  0.002496
# 2   SDSSXCS-290  2.961604  0.369827  0.382523  0.427969  0.002132  0.002098
# 3  SDSSXCS-1018  5.067958  1.015270  0.969362  0.210208  0.001929  0.001917
# 4   SDSSXCS-134  6.802619  0.782566  0.772819  0.767290  0.002149  0.002170
# 5   SDSSXCS-119       NaN       NaN       NaN       NaN       NaN       NaN
#
#     Mhy2500  Mhy2500-  Mhy2500+    Mg2500   Mg2500-   Mg2500+  Mhy500_wraderr  \
# 0  2.621329  0.112240  0.137975  0.321744  0.000722  0.000734        7.635562
# 1  1.602926  0.101929  0.109311  0.097414  0.000324  0.000329        7.823912
# 2  1.467429  0.175603  0.290465  0.134154  0.000759  0.000773        2.959792
# 3  1.128892  0.103503  0.149913  0.084371  0.000350  0.000359        5.072697
# ...

# %% [markdown]
# ### Combining tables

# %%
sdssxcs_samp = pd.merge(sdssxcs_base, sdssxcs_txlx, left_on='name', right_on='name', how='outer')
sdssxcs_samp = pd.merge(sdssxcs_samp, sdssxcs_mass, left_on='name', right_on='name', how='outer')

# %% [markdown]
# ### Scatter-dominating-excluded $M^{\rm{tot}}_{2500}$-$M^{\rm{gas}}_{2500}$

# %%
with open('../../outputs/scaling_relations/sdssrm-xcs_new/mtot-mgas/scatter_dominating_excluded/'\
          'turner2025_scatter-dom-exc_mtot2500_mgas2500.xgarel', 'rb') as scalo:
    mtot2500_mgas2500 = pickle.load(scalo)

# %% [markdown]
# ### Scatter-dominating-excluded $M^{\rm{tot}}_{500}$-$M^{\rm{gas}}_{500}$

# %%
with open('../../outputs/scaling_relations/sdssrm-xcs_new/mtot-mgas/scatter_dominating_excluded/'\
          'turner2025_scatter-dom-exc_mtot500_mgas500.xgarel', 'rb') as scalo:
    mtot500_mgas500 = pickle.load(scalo)

# %% [markdown]
# ## Splitting the datasets

# %% [markdown]
# We split the dataset (for $M^{\rm{tot/gas}}_{2500}$ _and_ $M^{\rm{tot/gas}}_{500}$) in two, so that both subsets can be fit with scaling relations separately in order to assess their relative scatter.

# %%
mgas2500_split = Quantity(2.e+13, 'Msun')
mgas500_split = Quantity(6e+13, 'Msun')

# %% [markdown]
# ### $M^{\rm{tot}}_{2500}$-$M^{\rm{gas}}_{2500}$

# %% [markdown]
# #### Removing scatter-dominating clusters

# %% [markdown]
# In the jackknifing analysis of the new SDSSRM-XCS $M_{\rm{tot}}$-$M_{\rm{gas}}$ relations, we identified galaxy clusters with an outsize contribution to the overall measured scatter of the relations ('scatter dominating clusters'). In order to get the clearest answer as to whether there is a change in scatter depending on the gas mass, we will exclude the scatter dominating datapoints.
#
# The jackknifing results for the $M^{\rm{tot}}_{2500}$-$M^{\rm{gas}}_{2500}$ are loaded in:

# %%
l1_mtot2500_mgas2500_res = pd.read_csv("../../outputs/result_files/exploring_scatter/leave_one_jackknife"\
                                       "/mtot-mgas/mtot2500_mgas2500_l1_jackknife_rel_pars.csv")
l1_mtot2500_mgas2500_res
# Out:
#    dropped_cluster   slope  slope+-    norm  norm+-  scatter  scatter+-  \
# 0     SDSSXCS-1018  0.5748   0.0454  1.3454  0.0547   0.1510     0.0138
# 1    SDSSXCS-10401  0.5581   0.0449  1.3603  0.0540   0.1464     0.0135
# 2      SDSSXCS-110  0.5702   0.0449  1.3363  0.0533   0.1483     0.0136
# 3    SDSSXCS-11154  0.5749   0.0452  1.3496  0.0545   0.1501     0.0137
# 4     SDSSXCS-1131  0.5749   0.0452  1.3454  0.0544   0.1505     0.0137
# ..             ...     ...      ...     ...     ...      ...        ...
# 86     SDSSXCS-907  0.5757   0.0457  1.3448  0.0545   0.1511     0.0138
# 87    SDSSXCS-9258  0.5890   0.0462  1.3347  0.0540   0.1495     0.0136
# 88    SDSSXCS-9313  0.5763   0.0458  1.3427  0.0548   0.1511     0.0138
# 89     SDSSXCS-944  0.5728   0.0455  1.3479  0.0546   0.1505     0.0137
# 90    SDSSXCS-9803  0.5763   0.0452  1.3497  0.0545   0.1500     0.0137
#
#     scatter_perc_change
# 0                 0.733
# 1                -2.373
# 2                -1.117
# ...

# %% [markdown]
# Identifying scatter-dominating clusters using the same confidence limit as the 'dominating excluded' scaling relations:

# %%
cur_low = np.percentile(l1_mtot2500_mgas2500_res['scatter_perc_change'].values, (50-(CONF_PERC/2)))

l1_mtot2500_mgas2500_domin = l1_mtot2500_mgas2500_res[l1_mtot2500_mgas2500_res['scatter_perc_change'] < cur_low]
l1_mtot2500_mgas2500_domin
# Out:
#    dropped_cluster   slope  slope+-    norm  norm+-  scatter  scatter+-  \
# 19     SDSSXCS-176  0.5924   0.0445  1.3279  0.0523   0.1449     0.0134
# 55     SDSSXCS-457  0.5830   0.0442  1.3565  0.0534   0.1455     0.0134
# 60    SDSSXCS-5159  0.6121   0.0451  1.3219  0.0517   0.1432     0.0129
# 61    SDSSXCS-5225  0.5684   0.0438  1.3610  0.0532   0.1445     0.0134
# 82    SDSSXCS-8060  0.5980   0.0439  1.3245  0.0514   0.1421     0.0132
#
#     scatter_perc_change
# 19               -3.383
# 55               -2.935
# 60               -4.490
# 61               -3.644
# 82               -5.226

# %% [markdown]
# Removing those clusters from our dataset:

# %%
dom_excl_sdssxcs_samp2500 = sdssxcs_samp[(~sdssxcs_samp['name'].isin(l1_mtot2500_mgas2500_domin['dropped_cluster'].values)) & 
                                         (sdssxcs_samp['name'].isin(l1_mtot2500_mgas2500_res['dropped_cluster'].values))]

# %% [markdown]
# #### Splitting the sample

# %%
above_samp2500 = dom_excl_sdssxcs_samp2500[Quantity(dom_excl_sdssxcs_samp2500['Mg2500_wraderr']*1e+14, 'Msun') >= mgas2500_split]
below_samp2500 = dom_excl_sdssxcs_samp2500[Quantity(dom_excl_sdssxcs_samp2500['Mg2500_wraderr']*1e+14, 'Msun') < mgas2500_split]

# %% [markdown]
# ### $M^{\rm{tot}}_{500}$-$M^{\rm{gas}}_{500}$

# %% [markdown]
# #### Removing scatter-dominating clusters

# %%
l1_mtot500_mgas500_res = pd.read_csv("../../outputs/result_files/exploring_scatter/leave_one_jackknife"\
                                     "/mtot-mgas/mtot500_mgas500_l1_jackknife_rel_pars.csv")
l1_mtot500_mgas500_res
# Out:
#     dropped_cluster   slope  slope+-    norm  norm+-  scatter  scatter+-  \
# 0      SDSSXCS-1018  0.4360   0.0613  2.5337  0.2379   0.2369     0.0196
# 1     SDSSXCS-10401  0.4189   0.0605  2.6271  0.2439   0.2317     0.0194
# 2       SDSSXCS-110  0.4349   0.0603  2.5232  0.2324   0.2338     0.0194
# 3     SDSSXCS-11154  0.4344   0.0611  2.5598  0.2393   0.2368     0.0196
# 4      SDSSXCS-1131  0.4332   0.0609  2.5550  0.2377   0.2362     0.0195
# ..              ...     ...      ...     ...     ...      ...        ...
# 99      SDSSXCS-907  0.4291   0.0614  2.5526  0.2382   0.2366     0.0196
# 100    SDSSXCS-9258  0.4353   0.0634  2.5451  0.2462   0.2374     0.0196
# 101    SDSSXCS-9313  0.4371   0.0615  2.5335  0.2390   0.2373     0.0196
# 102     SDSSXCS-944  0.4379   0.0611  2.5239  0.2365   0.2363     0.0196
# 103    SDSSXCS-9803  0.4343   0.0613  2.5608  0.2400   0.2365     0.0195
#
#      scatter_perc_change
# 0                  0.326
# 1                 -1.883
# ...

# %% [markdown]
# Identifying scatter-dominating clusters using the same confidence limit as the 'dominating excluded' scaling relations:

# %%
cur_low = np.percentile(l1_mtot500_mgas500_res['scatter_perc_change'].values, (50-(CONF_PERC/2)))

l1_mtot500_mgas500_domin = l1_mtot500_mgas500_res[l1_mtot500_mgas500_res['scatter_perc_change'] < cur_low]
l1_mtot500_mgas500_domin
# Out:
#    dropped_cluster   slope  slope+-    norm  norm+-  scatter  scatter+-  \
# 1    SDSSXCS-10401  0.4189   0.0605  2.6271  0.2439   0.2317     0.0194
# 34      SDSSXCS-22  0.4445   0.0576  2.5664  0.2256   0.2200     0.0188
# 36    SDSSXCS-2282  0.4261   0.0593  2.6102  0.2375   0.2285     0.0191
# 71    SDSSXCS-5159  0.4863   0.0618  2.3607  0.2220   0.2289     0.0187
# 86    SDSSXCS-6955  0.4184   0.0597  2.6323  0.2411   0.2294     0.0190
# 94    SDSSXCS-8060  0.4768   0.0599  2.3803  0.2182   0.2247     0.0190
#
#     scatter_perc_change
# 1                -1.883
# 34               -6.812
# 36               -3.203
# 71               -3.046
# 86               -2.830
# 94               -4.818

# %% [markdown]
# Removing those clusters from our dataset:

# %%
dom_excl_sdssxcs_samp500 = sdssxcs_samp[(~sdssxcs_samp['name'].isin(l1_mtot500_mgas500_domin['dropped_cluster'].values)) & 
                                        (sdssxcs_samp['name'].isin(l1_mtot500_mgas500_res['dropped_cluster'].values))]

# %% [markdown]
# #### Splitting the sample

# %%
above_samp500 = dom_excl_sdssxcs_samp500[Quantity(dom_excl_sdssxcs_samp500['Mg500_wraderr']*1e+14, 'Msun') >= mgas500_split]
below_samp500 = dom_excl_sdssxcs_samp500[Quantity(dom_excl_sdssxcs_samp500['Mg500_wraderr']*1e+14, 'Msun') < mgas500_split]

# %% [markdown]
# ## Fitting the relations

# %% [markdown]
# ### $M^{\rm{tot}}_{2500}$-$M^{\rm{gas}}_{2500}$

# %% [markdown]
# We can now fit the two sub-samples in exactly the same way as the original scaling relation was constructed.

# %% [markdown]
# #### $M^{\rm{tot}}_{2500}$-$M^{\rm{gas}}_{2500}$ [$M^{\rm{gas}}_{2500}\ge2\times10^{13}\:M_{\odot}$]

# %%
# Setting up property variables in astropy quantity objects
mtot2500 = Quantity(above_samp2500[['Mhy2500_wraderr', 'Mhy2500_wraderr-', 'Mhy2500_wraderr+']].values*1e+14, 'Msun')
mgas2500 = Quantity(above_samp2500[['Mg2500_wraderr', 'Mg2500_wraderr-', 'Mg2500_wraderr+']].values*1e+14, 'Msun')

mtot2500_mgas2500_above = scaling_relation_lira(mtot2500[:, 0], mtot2500[:, 1:], mgas2500[:, 0], mgas2500[:, 1:], m_norm, 
                                                mgas_norm, y_name=r"$M^{\rm{tot}}_{2500}$", x_name=r"$M^{\rm{gas}}_{2500}$", 
                                                point_names=above_samp2500['name'].values)
mtot2500_mgas2500_above.model_colour = 'darkgoldenrod'
mtot2500_mgas2500_above.author = 'Turner et al.'
mtot2500_mgas2500_above.year = 2025
mtot2500_mgas2500_above.name = r"$M^{\rm{gas}}_{2500} \geq 2\times10^{13}\:M_{\odot}$"
# Out:
# R[write to console]: module mix loaded
#   |**************************************************| 100%

# %%
print("Slope of {v:.3f} ± {e:.3f}\n".format(v=mtot2500_mgas2500_above.pars[0][0], e=mtot2500_mgas2500_above.pars[0][1]))
print("Normalisation of {v:.3f} ± {e:.3f}\n".format(v=mtot2500_mgas2500_above.pars[1][0], e=mtot2500_mgas2500_above.pars[1][1]))
print("Scatter of {v:.3f} ± {e:.3f}".format(v=mtot2500_mgas2500_above.scatter_par[0], e=mtot2500_mgas2500_above.scatter_par[1]))
# Out:
# Slope of 0.719 ± 0.100
#
# Normalisation of 1.291 ± 0.150
#
# Scatter of 0.057 ± 0.011

# %%
mtot2500_mgas2500_above.view(figsize=(7.3, 7), y_lims=Quantity([1e+13, 9e+14], 'Msun'))

# %% [markdown]
# #### $M^{\rm{tot}}_{2500}$-$M^{\rm{gas}}_{2500}$ [$M^{\rm{gas}}_{2500}\lt2\times10^{13}\:M_{\odot}$]

# %%
# Setting up property variables in astropy quantity objects
mtot2500 = Quantity(below_samp2500[['Mhy2500_wraderr', 'Mhy2500_wraderr-', 'Mhy2500_wraderr+']].values*1e+14, 'Msun')
mgas2500 = Quantity(below_samp2500[['Mg2500_wraderr', 'Mg2500_wraderr-', 'Mg2500_wraderr+']].values*1e+14, 'Msun')

mtot2500_mgas2500_below = scaling_relation_lira(mtot2500[:, 0], mtot2500[:, 1:], mgas2500[:, 0], mgas2500[:, 1:], m_norm, 
                                                mgas_norm, y_name=r"$M^{\rm{tot}}_{2500}$", x_name=r"$M^{\rm{gas}}_{2500}$", 
                                                point_names=below_samp2500['name'].values)
mtot2500_mgas2500_below.model_colour = 'darkcyan'
mtot2500_mgas2500_below.author = 'Turner et al.'
mtot2500_mgas2500_below.year = 2025
mtot2500_mgas2500_below.name = r"$M^{\rm{gas}}_{2500}<2\times10^{13}\:M_{\odot}$"
# Out:
#   |**************************************************| 100%

# %%
print("Slope of {v:.3f} ± {e:.3f}\n".format(v=mtot2500_mgas2500_below.pars[0][0], e=mtot2500_mgas2500_below.pars[0][1]))
print("Normalisation of {v:.3f} ± {e:.3f}\n".format(v=mtot2500_mgas2500_below.pars[1][0], e=mtot2500_mgas2500_below.pars[1][1]))
print("Scatter of {v:.3f} ± {e:.3f}".format(v=mtot2500_mgas2500_below.scatter_par[0], e=mtot2500_mgas2500_below.scatter_par[1]))
# Out:
# Slope of 0.580 ± 0.072
#
# Normalisation of 1.250 ± 0.061
#
# Scatter of 0.137 ± 0.016

# %%
mtot2500_mgas2500_below.view(figsize=(7.3, 7), y_lims=Quantity([1e+13, 9e+14], 'Msun'))

# %% [markdown]
# ### $M^{\rm{tot}}_{500}$-$M^{\rm{gas}}_{500}$

# %% [markdown]
# We can now fit the two sub-samples in exactly the same way as the original scaling relation was constructed.

# %% [markdown]
# #### $M^{\rm{tot}}_{500}$-$M^{\rm{gas}}_{500}$ [$M^{\rm{gas}}_{500}\ge6\times10^{13}\:M_{\odot}$]

# %%
# Setting up property variables in astropy quantity objects
mtot500 = Quantity(above_samp500[['Mhy500_wraderr', 'Mhy500_wraderr-', 'Mhy500_wraderr+']].values*1e+14, 'Msun')
mgas500 = Quantity(above_samp500[['Mg500_wraderr', 'Mg500_wraderr-', 'Mg500_wraderr+']].values*1e+14, 'Msun')

mtot500_mgas500_above = scaling_relation_lira(mtot500[:, 0], mtot500[:, 1:], mgas500[:, 0], mgas500[:, 1:], m_norm, 
                                              mgas_norm, y_name=r"$M^{\rm{tot}}_{500}$", x_name=r"$M^{\rm{gas}}_{500}$", 
                                              point_names=above_samp500['name'].values)
mtot500_mgas500_above.model_colour = 'darkgray'
mtot500_mgas500_above.author = 'Turner et al.'
mtot500_mgas500_above.year = 2025
mtot500_mgas500_above.name = r"$M^{\rm{gas}}_{500} \geq 6\times10^{13}\:M_{\odot}$"
# Out:
#   |**************************************************| 100%

# %%
print("Slope of {v:.3f} ± {e:.3f}\n".format(v=mtot500_mgas500_above.pars[0][0], e=mtot500_mgas500_above.pars[0][1]))
print("Normalisation of {v:.3f} ± {e:.3f}\n".format(v=mtot500_mgas500_above.pars[1][0], e=mtot500_mgas500_above.pars[1][1]))
print("Scatter of {v:.3f} ± {e:.3f}".format(v=mtot500_mgas500_above.scatter_par[0], e=mtot500_mgas500_above.scatter_par[1]))
# Out:
# Slope of 0.560 ± 0.189
#
# Normalisation of 2.450 ± 1.109
#
# Scatter of 0.106 ± 0.020

# %%
mtot500_mgas500_above.view(figsize=(7.3, 7), y_lims=Quantity([1e+13, 4e+15], 'Msun'))

# %% [markdown]
# #### $M^{\rm{tot}}_{500}$-$M^{\rm{gas}}_{500}$ [$M^{\rm{gas}}_{500}\lt6\times10^{13}\:M_{\odot}$]

# %%
# Setting up property variables in astropy quantity objects
mtot500 = Quantity(below_samp500[['Mhy500_wraderr', 'Mhy500_wraderr-', 'Mhy500_wraderr+']].values*1e+14, 'Msun')
mgas500 = Quantity(below_samp500[['Mg500_wraderr', 'Mg500_wraderr-', 'Mg500_wraderr+']].values*1e+14, 'Msun')

mtot500_mgas500_below = scaling_relation_lira(mtot500[:, 0], mtot500[:, 1:], mgas500[:, 0], mgas500[:, 1:], m_norm, 
                                              mgas_norm, y_name=r"$M^{\rm{tot}}_{500}$", x_name=r"$M^{\rm{gas}}_{500}$", 
                                              point_names=below_samp500['name'].values)
mtot500_mgas500_below.model_colour = 'navy'
mtot500_mgas500_below.author = 'Turner et al.'
mtot500_mgas500_below.year = 2025
mtot500_mgas500_below.name = r"$M^{\rm{gas}}_{500} < 6\times10^{13}\:M_{\odot}$"
# Out:
#   |**************************************************| 100%

# %%
print("Slope of {v:.3f} ± {e:.3f}\n".format(v=mtot500_mgas500_below.pars[0][0], e=mtot500_mgas500_below.pars[0][1]))
print("Normalisation of {v:.3f} ± {e:.3f}\n".format(v=mtot500_mgas500_below.pars[1][0], e=mtot500_mgas500_below.pars[1][1]))
print("Scatter of {v:.3f} ± {e:.3f}".format(v=mtot500_mgas500_below.scatter_par[0], e=mtot500_mgas500_below.scatter_par[1]))
# Out:
# Slope of 0.398 ± 0.092
#
# Normalisation of 2.543 ± 0.250
#
# Scatter of 0.203 ± 0.022

# %%
mtot500_mgas500_below.view(figsize=(7.3, 7), y_lims=Quantity([1e+13, 4e+15], 'Msun'))

# %% [markdown]
# ## Visualising the scaling relations

# %% [markdown]
# ### $M^{\rm{tot}}_{2500}$-$M^{\rm{tot}}_{2500}$

# %% [markdown]
# Our main goal here was to quantify the difference in scatter between the two sub-samples, but we also compare the two by visualising them in a single figure.

# %%
# Stupid bodge to make the relation figure labels plot properly
mtot2500_mgas2500_below.author = 'XGA'
mtot2500_mgas2500_above.author = 'XGA'
mtot2500_mgas2500.author = 'XGA'
# Modifying the loaded mtot2500-mgas2500 relation so it won't show any data points
mtot2500_mgas2500.name = r'All $M^{\rm{gas}}_{2500}$'

(mtot2500_mgas2500_below + mtot2500_mgas2500_above + 
     mtot2500_mgas2500).view(figsize=(7.3, 7), y_lims=Quantity([1e+13, 9e+14], 'Msun'), 
                             save_path="../../outputs/figures/exploring_scatter/mtot2500_mgas2500_scatter_mgas_dep.pdf",
                             data_colour_list=[mtot2500_mgas2500_below.model_colour,
                                               'peru',
                                               'None'])

mtot2500_mgas2500_below.author = 'Turner et al.'
mtot2500_mgas2500_above.author = 'Turner et al.'
mtot2500_mgas2500.author = 'Turner et al.'

# %% [markdown]
# We also make a corner plot with both relations:

# %%
(mtot2500_mgas2500_below + mtot2500_mgas2500_above + mtot2500_mgas2500).view_corner(figsize=(6.5, 6.5), 
                                                                save_path="../../outputs/figures/exploring_scatter/"\
                                                                          "mtot2500_mgas2500_scatter_mgas_dep_contours.pdf")
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in

# %% [markdown]
# ### $M^{\rm{tot}}_{500}$-$M^{\rm{tot}}_{500}$

# %%
# Stupid bodge to make the relation figure labels plot properly
mtot500_mgas500_below.author = 'XGA'
mtot500_mgas500_above.author = 'XGA'
mtot500_mgas500.author = 'XGA'
# Modifying the loaded mtot500-mgas500 relation so it won't show any data points
mtot500_mgas500.name = r'All $M^{\rm{gas}}_{500}$'

(mtot500_mgas500_below + mtot500_mgas500_above + 
     mtot500_mgas500).view(figsize=(7.3, 7), y_lims=Quantity([1e+13, 4e+15], 'Msun'), 
                             save_path="../../outputs/figures/exploring_scatter/mtot500_mgas500_scatter_mgas_dep.pdf",
                             data_colour_list=[mtot500_mgas500_below.model_colour,
                                               'dimgray',
                                               'None'])

mtot500_mgas500_below.author = 'Turner et al.'
mtot500_mgas500_above.author = 'Turner et al.'
mtot500_mgas500.author = 'Turner et al.'

# %%
(mtot500_mgas500_below + mtot500_mgas500_above + 
     mtot500_mgas500).view_corner(figsize=(6.5, 6.5), save_path="../../outputs/figures/exploring_scatter/"\
                                                                "mtot500_mgas500_scatter_mgas_dep_contours.pdf")
# Out:
# Removed no burn in
# Removed no burn in
# Removed no burn in
